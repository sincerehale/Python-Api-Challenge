# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

#Define the Unit to Metric
units = "metric"

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city + "&appid=" + weather_api_key + "&units="+ units
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 2 of Set 1 | talnakh
# Processing Record 3 of Set 1 | badger
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | ilulissat
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | bonthe
# Processing Record 8 of Set 1 | ankazoabo
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | hadibu
# Processing Record 11 of Set 1 | klaksvik
# Processing Record 12 of Set 1 | addis ababa
# Processing Record 13 of Set 1 | dezhou
# Processing Record 14 of Set 1 | edinburgh of the seven seas
# Processing Record 15 of Set 1 | margaret river
# Processing Record 16 of Set 1 | northam
# Processing Record 17 of Set 1 | aasiaat
# Processing Record 18 of Set 1 | weno
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | isafjordur
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | gombong
# Processing Record 24 of Set 1 | hammerfest
# Processing Record 25 of Set 1 | la palma
# Processing Record 26 of Set 1 | brookings
# Processing Record 27 of Set 1 | udachny
# Processing Record 28 of Set 1 | taco pozo
# Processing Record 29 of Set 1 | santiago de cuba
# Processing Record 30 of Set 1 | bogale
# Processing Record 31 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 32 of Set 1 | thunder bay
# Processing Record 33 of Set 1 | puerto berrio
# Processing Record 34 of Set 1 | bani yas city
# City not found. Skipping...
# Processing Record 35 of Set 1 | priozersk
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | adamstown
# Processing Record 40 of Set 1 | utrik
# Processing Record 41 of Set 1 | atafu village
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | tura
# Processing Record 44 of Set 1 | gorontalo
# Processing Record 45 of Set 1 | kimbe
# Processing Record 46 of Set 1 | tegueste
# Processing Record 47 of Set 1 | binji
# Processing Record 48 of Set 1 | dolores
# Processing Record 49 of Set 1 | colares
# Processing Record 50 of Set 1 | menongue
# Processing Record 0 of Set 2 | papatowai
# Processing Record 1 of Set 2 | klyuchi
# Processing Record 2 of Set 2 | acarau
# Processing Record 3 of Set 2 | springbok
# Processing Record 4 of Set 2 | kill devil hills
# Processing Record 5 of Set 2 | tofol
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | kamimaruko
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | sarangani
# Processing Record 10 of Set 2 | puerto natales
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | illizi
# Processing Record 13 of Set 2 | vila franca do campo
# Processing Record 14 of Set 2 | aras-asan
# Processing Record 15 of Set 2 | aldan
# Processing Record 16 of Set 2 | port saint john's
# Processing Record 17 of Set 2 | vengurla
# Processing Record 18 of Set 2 | fort mcmurray
# Processing Record 19 of Set 2 | inhambane
# Processing Record 20 of Set 2 | fayroz koh
# Processing Record 21 of Set 2 | harnai
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | holualoa
# Processing Record 24 of Set 2 | piti village
# Processing Record 25 of Set 2 | invercargill
# Processing Record 26 of Set 2 | lihue
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | galliano
# Processing Record 29 of Set 2 | necochea
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | nabire
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | labrador city
# Processing Record 35 of Set 2 | gadzhiyevo
# Processing Record 36 of Set 2 | pisco
# Processing Record 37 of Set 2 | polyarnyy
# Processing Record 38 of Set 2 | bilibino
# Processing Record 39 of Set 2 | sinabang
# Processing Record 40 of Set 2 | isabela
# Processing Record 41 of Set 2 | qaqortoq
# Processing Record 42 of Set 2 | blackmans bay
# Processing Record 43 of Set 2 | la passe
# Processing Record 44 of Set 2 | pierre
# Processing Record 45 of Set 2 | paragould
# Processing Record 46 of Set 2 | constitucion
# Processing Record 47 of Set 2 | knysna
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | gorno-altaysk
# Processing Record 0 of Set 3 | east london
# Processing Record 1 of Set 3 | petoskey
# Processing Record 2 of Set 3 | ancud
# Processing Record 3 of Set 3 | ruswil
# Processing Record 4 of Set 3 | vorgashor
# Processing Record 5 of Set 3 | goure
# Processing Record 6 of Set 3 | sao martinho
# Processing Record 7 of Set 3 | lovington
# Processing Record 8 of Set 3 | nagqu
# Processing Record 9 of Set 3 | darnah
# Processing Record 10 of Set 3 | saipan
# Processing Record 11 of Set 3 | flying fish cove
# Processing Record 12 of Set 3 | guilmaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | kayangel
# Processing Record 14 of Set 3 | vadso
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | port lincoln
# Processing Record 17 of Set 3 | suva
# Processing Record 18 of Set 3 | paramonga
# Processing Record 19 of Set 3 | novodvinsk
# Processing Record 20 of Set 3 | huarmey
# Processing Record 21 of Set 3 | berlin
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | bubaque
# Processing Record 24 of Set 3 | upington
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | olonkinbyen
# Processing Record 27 of Set 3 | west island
# Processing Record 28 of Set 3 | eldivan
# Processing Record 29 of Set 3 | gisborne
# Processing Record 30 of Set 3 | college
# Processing Record 31 of Set 3 | susuman
# Processing Record 32 of Set 3 | kingston
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 35 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | kalavoor
# City not found. Skipping...
# Processing Record 38 of Set 3 | embi
# Processing Record 39 of Set 3 | colonia
# Processing Record 40 of Set 3 | guanica
# Processing Record 41 of Set 3 | hirara
# Processing Record 42 of Set 3 | ko pha ngan
# Processing Record 43 of Set 3 | san antonio de pale
# Processing Record 44 of Set 3 | puerto aysen
# Processing Record 45 of Set 3 | were ilu
# Processing Record 46 of Set 3 | kibaha
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | bandarbeyla
# Processing Record 49 of Set 3 | ust-nera
# Processing Record 0 of Set 4 | port elizabeth
# Processing Record 1 of Set 4 | guarapari
# Processing Record 2 of Set 4 | iskateley
# Processing Record 3 of Set 4 | sant antoni de portmany
# Processing Record 4 of Set 4 | broken hill
# Processing Record 5 of Set 4 | nadym
# Processing Record 6 of Set 4 | ulsteinvik
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | kourou
# Processing Record 9 of Set 4 | alice springs
# Processing Record 10 of Set 4 | haiku-pauwela
# Processing Record 11 of Set 4 | chonchi
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | uliastay
# Processing Record 14 of Set 4 | monteria
# Processing Record 15 of Set 4 | thinadhoo
# Processing Record 16 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 17 of Set 4 | banda aceh
# Processing Record 18 of Set 4 | chayan
# Processing Record 19 of Set 4 | sinop
# Processing Record 20 of Set 4 | xilin hot
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | bela
# Processing Record 24 of Set 4 | saint croix
# Processing Record 25 of Set 4 | sekong
# Processing Record 26 of Set 4 | boguchany
# Processing Record 27 of Set 4 | padangsidempuan
# Processing Record 28 of Set 4 | smithers
# Processing Record 29 of Set 4 | stanley
# Processing Record 30 of Set 4 | elliot lake
# Processing Record 31 of Set 4 | vilyuchinsk
# Processing Record 32 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 33 of Set 4 | amga
# Processing Record 34 of Set 4 | tolanaro
# Processing Record 35 of Set 4 | yuzhno-kurilsk
# Processing Record 36 of Set 4 | constantia
# Processing Record 37 of Set 4 | fedorovskiy
# Processing Record 38 of Set 4 | conception bay south
# Processing Record 39 of Set 4 | churapcha
# Processing Record 40 of Set 4 | forbes
# Processing Record 41 of Set 4 | hithadhoo
# Processing Record 42 of Set 4 | kirensk
# Processing Record 43 of Set 4 | hawaiian paradise park
# Processing Record 44 of Set 4 | leiyang
# Processing Record 45 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 4 | jamestown
# Processing Record 47 of Set 4 | manokwari
# Processing Record 48 of Set 4 | al fuwayliq
# Processing Record 49 of Set 4 | oeiras do para
# Processing Record 0 of Set 5 | nevel'sk
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | mayna
# Processing Record 3 of Set 5 | quellon
# Processing Record 4 of Set 5 | khandyga
# Processing Record 5 of Set 5 | anadyr
# Processing Record 6 of Set 5 | minas de marcona
# Processing Record 7 of Set 5 | malango
# Processing Record 8 of Set 5 | bamboo flat
# Processing Record 9 of Set 5 | kawthoung
# City not found. Skipping...
# Processing Record 10 of Set 5 | boqueirao
# Processing Record 11 of Set 5 | mahibadhoo
# Processing Record 12 of Set 5 | waverly
# Processing Record 13 of Set 5 | dudinka
# Processing Record 14 of Set 5 | hotan
# Processing Record 15 of Set 5 | regina
# Processing Record 16 of Set 5 | thames
# Processing Record 17 of Set 5 | rocha
# Processing Record 18 of Set 5 | taro
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | alice
# Processing Record 21 of Set 5 | lubango
# Processing Record 22 of Set 5 | fort bragg
# Processing Record 23 of Set 5 | nago
# Processing Record 24 of Set 5 | visakhapatnam
# Processing Record 25 of Set 5 | codrington
# Processing Record 26 of Set 5 | benghazi
# Processing Record 27 of Set 5 | tweed heads
# Processing Record 28 of Set 5 | boulder city
# Processing Record 29 of Set 5 | manismata
# Processing Record 30 of Set 5 | remire-montjoly
# Processing Record 31 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 5 | papao
# Processing Record 33 of Set 5 | st. john's
# Processing Record 34 of Set 5 | kidal
# Processing Record 35 of Set 5 | trairi
# Processing Record 36 of Set 5 | nadi
# Processing Record 37 of Set 5 | kharp
# Processing Record 38 of Set 5 | cerritos
# Processing Record 39 of Set 5 | kedougou
# Processing Record 40 of Set 5 | oyama
# Processing Record 41 of Set 5 | rawson
# Processing Record 42 of Set 5 | klyavlino
# Processing Record 43 of Set 5 | lycksele
# Processing Record 44 of Set 5 | argo
# Processing Record 45 of Set 5 | guaruja
# Processing Record 46 of Set 5 | daru
# Processing Record 47 of Set 5 | ixtapa
# Processing Record 48 of Set 5 | crane
# Processing Record 49 of Set 5 | kingscliff
# Processing Record 0 of Set 6 | maumere
# Processing Record 1 of Set 6 | senador jose porfirio
# Processing Record 2 of Set 6 | wotho
# Processing Record 3 of Set 6 | suai
# City not found. Skipping...
# Processing Record 4 of Set 6 | fale old settlement
# Processing Record 5 of Set 6 | bandar abbas
# Processing Record 6 of Set 6 | kstovo
# Processing Record 7 of Set 6 | tchintabaraden
# Processing Record 8 of Set 6 | karachev
# Processing Record 9 of Set 6 | olenino
# Processing Record 10 of Set 6 | puerto armuelles
# Processing Record 11 of Set 6 | ivdel'
# Processing Record 12 of Set 6 | nuku'alofa
# Processing Record 13 of Set 6 | upper grand lagoon
# Processing Record 14 of Set 6 | karratha
# Processing Record 15 of Set 6 | senillosa
# Processing Record 16 of Set 6 | boende
# Processing Record 17 of Set 6 | huntsville
# Processing Record 18 of Set 6 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 19 of Set 6 | suntar
# Processing Record 20 of Set 6 | las navas del marques
# Processing Record 21 of Set 6 | uri
# Processing Record 22 of Set 6 | afaahiti
# Processing Record 23 of Set 6 | valerik
# Processing Record 24 of Set 6 | sabang
# Processing Record 25 of Set 6 | tazacorte
# Processing Record 26 of Set 6 | savran
# Processing Record 27 of Set 6 | west end village
# City not found. Skipping...
# Processing Record 28 of Set 6 | qadirpur ran
# Processing Record 29 of Set 6 | krasnyy chikoy
# Processing Record 30 of Set 6 | port mathurin
# Processing Record 31 of Set 6 | cidade velha
# Processing Record 32 of Set 6 | astoria
# Processing Record 33 of Set 6 | inyonga
# Processing Record 34 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 35 of Set 6 | charlotte amalie
# Processing Record 36 of Set 6 | queenstown
# Processing Record 37 of Set 6 | turabah
# Processing Record 38 of Set 6 | panaba
# Processing Record 39 of Set 6 | georgievka
# Processing Record 40 of Set 6 | prince rupert
# Processing Record 41 of Set 6 | walvis bay
# Processing Record 42 of Set 6 | korla
# Processing Record 43 of Set 6 | wailua homesteads
# Processing Record 44 of Set 6 | kailua-kona
# Processing Record 45 of Set 6 | lata
# Processing Record 46 of Set 6 | grand-lahou
# Processing Record 47 of Set 6 | puerto san jose
# Processing Record 48 of Set 6 | kapa'a
# Processing Record 49 of Set 6 | mohr
# Processing Record 0 of Set 7 | keflavik
# Processing Record 1 of Set 7 | sangueya
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | aykhal
# Processing Record 4 of Set 7 | ola
# Processing Record 5 of Set 7 | whitehorse
# Processing Record 6 of Set 7 | murghob
# Processing Record 7 of Set 7 | benguela
# Processing Record 8 of Set 7 | kananga
# Processing Record 9 of Set 7 | jiangkou
# Processing Record 10 of Set 7 | mejit
# Processing Record 11 of Set 7 | da nang
# Processing Record 12 of Set 7 | abalak
# Processing Record 13 of Set 7 | puerto baquerizo moreno
# Processing Record 14 of Set 7 | nova vicosa
# Processing Record 15 of Set 7 | sittwe
# Processing Record 16 of Set 7 | onguday
# Processing Record 17 of Set 7 | malabar
# Processing Record 18 of Set 7 | isangel
# Processing Record 19 of Set 7 | accra
# Processing Record 20 of Set 7 | stendal
# Processing Record 21 of Set 7 | atlanta
# Processing Record 22 of Set 7 | nogliki
# Processing Record 23 of Set 7 | sarina
# Processing Record 24 of Set 7 | new norfolk
# Processing Record 25 of Set 7 | tazovsky
# Processing Record 26 of Set 7 | tara
# Processing Record 27 of Set 7 | sumperk
# Processing Record 28 of Set 7 | nuuk
# Processing Record 29 of Set 7 | mokhsogollokh
# Processing Record 30 of Set 7 | bryne
# Processing Record 31 of Set 7 | greymouth
# Processing Record 32 of Set 7 | mitsamiouli
# Processing Record 33 of Set 7 | novosergiyevka
# Processing Record 34 of Set 7 | wynyard
# Processing Record 35 of Set 7 | sault ste. marie
# Processing Record 36 of Set 7 | bondo
# Processing Record 37 of Set 7 | bunbury
# Processing Record 38 of Set 7 | nemuro
# Processing Record 39 of Set 7 | cidreira
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | coquimbo
# Processing Record 42 of Set 7 | waingapu
# Processing Record 43 of Set 7 | vilyuysk
# Processing Record 44 of Set 7 | duyun
# Processing Record 45 of Set 7 | kulachi
# Processing Record 46 of Set 7 | zapala
# Processing Record 47 of Set 7 | itaituba
# Processing Record 48 of Set 7 | naifaru
# Processing Record 49 of Set 7 | taulaga
# Processing Record 0 of Set 8 | nahiyat ash shinafiyah
# Processing Record 1 of Set 8 | galesong
# Processing Record 2 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 3 of Set 8 | berdigestyakh
# Processing Record 4 of Set 8 | uturoa
# Processing Record 5 of Set 8 | guerrero negro
# Processing Record 6 of Set 8 | egilsstadir
# Processing Record 7 of Set 8 | vanimo
# Processing Record 8 of Set 8 | zuromin
# Processing Record 9 of Set 8 | taoudenni
# Processing Record 10 of Set 8 | verkhov'ye
# Processing Record 11 of Set 8 | rongelap
# Processing Record 12 of Set 8 | chifeng
# Processing Record 13 of Set 8 | tabou
# Processing Record 14 of Set 8 | sisimiut
# Processing Record 15 of Set 8 | shetpe
# Processing Record 16 of Set 8 | shitanjing
# Processing Record 17 of Set 8 | antofagasta
# Processing Record 18 of Set 8 | happy valley-goose bay
# Processing Record 19 of Set 8 | solleftea
# Processing Record 20 of Set 8 | ternate
# Processing Record 21 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 8 | marka
# Processing Record 23 of Set 8 | pandan
# Processing Record 24 of Set 8 | fortuna
# Processing Record 25 of Set 8 | muskogee
# Processing Record 26 of Set 8 | lethem
# Processing Record 27 of Set 8 | nalut
# Processing Record 28 of Set 8 | vozhega
# Processing Record 29 of Set 8 | karatau
# Processing Record 30 of Set 8 | turbiv
# Processing Record 31 of Set 8 | kafue
# Processing Record 32 of Set 8 | an nuhud
# Processing Record 33 of Set 8 | kasongo-lunda
# Processing Record 34 of Set 8 | mugumu
# Processing Record 35 of Set 8 | salekhard
# Processing Record 36 of Set 8 | tucuma
# Processing Record 37 of Set 8 | nangal
# Processing Record 38 of Set 8 | ingeniero jacobacci
# Processing Record 39 of Set 8 | anabar
# City not found. Skipping...
# Processing Record 40 of Set 8 | taunsa
# Processing Record 41 of Set 8 | sirjan
# Processing Record 42 of Set 8 | cole harbour
# Processing Record 43 of Set 8 | hami
# Processing Record 44 of Set 8 | tari
# Processing Record 45 of Set 8 | harper
# Processing Record 46 of Set 8 | kalmunai
# Processing Record 47 of Set 8 | erenhot
# Processing Record 48 of Set 8 | altamira
# Processing Record 49 of Set 8 | hilo
# Processing Record 0 of Set 9 | bukama
# Processing Record 1 of Set 9 | kitee
# Processing Record 2 of Set 9 | kamaishi
# Processing Record 3 of Set 9 | conde
# Processing Record 4 of Set 9 | al ghayzah
# Processing Record 5 of Set 9 | manjeshvar
# Processing Record 6 of Set 9 | al jawf
# Processing Record 7 of Set 9 | cadale
# Processing Record 8 of Set 9 | luganville
# Processing Record 9 of Set 9 | kasserine
# Processing Record 10 of Set 9 | alakurtti
# Processing Record 11 of Set 9 | katsuura
# Processing Record 12 of Set 9 | muisne
# Processing Record 13 of Set 9 | nar'yan-mar
# Processing Record 14 of Set 9 | sanming
# Processing Record 15 of Set 9 | kuta
# Processing Record 16 of Set 9 | swakopmund
# Processing Record 17 of Set 9 | ljusdal
# Processing Record 18 of Set 9 | geroskipou
# City not found. Skipping...
# Processing Record 19 of Set 9 | middelburg
# Processing Record 20 of Set 9 | nukunonu
# City not found. Skipping...
# Processing Record 21 of Set 9 | alaminos
# Processing Record 22 of Set 9 | eyl
# Processing Record 23 of Set 9 | ocean city
# Processing Record 24 of Set 9 | motueka
# Processing Record 25 of Set 9 | kalemie
# Processing Record 26 of Set 9 | odesskoye
# Processing Record 27 of Set 9 | praia da vitoria
# Processing Record 28 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 29 of Set 9 | xifeng
# Processing Record 30 of Set 9 | buala
# Processing Record 31 of Set 9 | mcrae
# Processing Record 32 of Set 9 | krumovgrad
# Processing Record 33 of Set 9 | kenai
# Processing Record 34 of Set 9 | strezhevoy
# Processing Record 35 of Set 9 | zhumysker
# Processing Record 36 of Set 9 | la ronge
# Processing Record 37 of Set 9 | cabedelo
# Processing Record 38 of Set 9 | manatutu
# City not found. Skipping...
# Processing Record 39 of Set 9 | joao pinheiro
# Processing Record 40 of Set 9 | el prat de llobregat
# Processing Record 41 of Set 9 | bani walid
# Processing Record 42 of Set 9 | calvinia
# Processing Record 43 of Set 9 | nova sintra
# Processing Record 44 of Set 9 | mount pearl
# Processing Record 45 of Set 9 | casper
# Processing Record 46 of Set 9 | oral
# Processing Record 47 of Set 9 | tonsberg
# Processing Record 48 of Set 9 | touros
# Processing Record 49 of Set 9 | ayaguz
# City not found. Skipping...
# Processing Record 0 of Set 10 | cascais
# Processing Record 1 of Set 10 | andovoranto
# Processing Record 2 of Set 10 | abu al matamir
# Processing Record 3 of Set 10 | birao
# Processing Record 4 of Set 10 | gedo
# Processing Record 5 of Set 10 | sao vicente
# Processing Record 6 of Set 10 | sho'rchi
# Processing Record 7 of Set 10 | saint-francois
# Processing Record 8 of Set 10 | west salem
# Processing Record 9 of Set 10 | island harbour
# Processing Record 10 of Set 10 | enewetak
# Processing Record 11 of Set 10 | rabo de peixe
# Processing Record 12 of Set 10 | plouzane
# Processing Record 13 of Set 10 | bakchar
# Processing Record 14 of Set 10 | ratne
# Processing Record 15 of Set 10 | shangmei
# Processing Record 16 of Set 10 | dhidhdhoo
# Processing Record 17 of Set 10 | praia
# Processing Record 18 of Set 10 | santa cruz de tenerife
# Processing Record 19 of Set 10 | burang
# Processing Record 20 of Set 10 | rampur
# Processing Record 21 of Set 10 | la'ie
# Processing Record 22 of Set 10 | vallenar
# Processing Record 23 of Set 10 | novoagansk
# Processing Record 24 of Set 10 | port said
# Processing Record 25 of Set 10 | mchinji
# Processing Record 26 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 27 of Set 10 | kultali
# City not found. Skipping...
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | camabatela
# Processing Record 30 of Set 10 | maxixe
# Processing Record 31 of Set 10 | labasa
# Processing Record 32 of Set 10 | tvoroyri
# Processing Record 33 of Set 10 | shimoda
# Processing Record 34 of Set 10 | selfoss
# Processing Record 35 of Set 10 | portland
# Processing Record 36 of Set 10 | slave lake
# Processing Record 37 of Set 10 | adapazari
# Processing Record 38 of Set 10 | cockburn town
# Processing Record 39 of Set 10 | patnanungan
# Processing Record 40 of Set 10 | oppdal
# Processing Record 41 of Set 10 | beira
# Processing Record 42 of Set 10 | bandar lampung
# Processing Record 43 of Set 10 | machico
# Processing Record 44 of Set 10 | elmendorf air force base
# City not found. Skipping...
# Processing Record 45 of Set 10 | ouallam
# Processing Record 46 of Set 10 | namibe
# Processing Record 47 of Set 10 | obo
# Processing Record 48 of Set 10 | putyvl'
# Processing Record 49 of Set 10 | horsham
# Processing Record 0 of Set 11 | borodulikha
# Processing Record 1 of Set 11 | les anglais
# Processing Record 2 of Set 11 | elverum
# Processing Record 3 of Set 11 | beinamar
# Processing Record 4 of Set 11 | sao joao da barra
# Processing Record 5 of Set 11 | newman
# Processing Record 6 of Set 11 | labytnangi
# Processing Record 7 of Set 11 | tevragh zeina
# City not found. Skipping...
# Processing Record 8 of Set 11 | gamba
# Processing Record 9 of Set 11 | muli
# Processing Record 10 of Set 11 | worland
# Processing Record 11 of Set 11 | mount isa
# Processing Record 12 of Set 11 | abohar
# Processing Record 13 of Set 11 | arkalyk
# Processing Record 14 of Set 11 | lucas
# Processing Record 15 of Set 11 | dalai
# Processing Record 16 of Set 11 | brasilia
# Processing Record 17 of Set 11 | sanghar
# Processing Record 18 of Set 11 | presidente epitacio
# Processing Record 19 of Set 11 | tchaourou
# Processing Record 20 of Set 11 | mccook
# Processing Record 21 of Set 11 | sambek
# Processing Record 22 of Set 11 | bardai
# Processing Record 23 of Set 11 | zambezi
# Processing Record 24 of Set 11 | mysen
# Processing Record 25 of Set 11 | fes al bali
# Processing Record 26 of Set 11 | pemba
# Processing Record 27 of Set 11 | kijang
# Processing Record 28 of Set 11 | napier
# Processing Record 29 of Set 11 | port alfred
# Processing Record 30 of Set 11 | north bend
# Processing Record 31 of Set 11 | kununurra
# Processing Record 32 of Set 11 | caleta de carquin
# Processing Record 33 of Set 11 | santana
# Processing Record 34 of Set 11 | mogadishu
# Processing Record 35 of Set 11 | andergrove
# Processing Record 36 of Set 11 | berezovyy
# Processing Record 37 of Set 11 | azul
# Processing Record 38 of Set 11 | zarghun shahr
# Processing Record 39 of Set 11 | kerikeri
# Processing Record 40 of Set 11 | rudbar
# Processing Record 41 of Set 11 | saint-louis
# Processing Record 42 of Set 11 | markala
# Processing Record 43 of Set 11 | coahuayana de hidalgo
# Processing Record 44 of Set 11 | hereford
# Processing Record 45 of Set 11 | zaozersk
# Processing Record 46 of Set 11 | mombetsu
# Processing Record 47 of Set 11 | copiapo
# Processing Record 48 of Set 11 | quepos
# Processing Record 49 of Set 11 | debre werk'
# Processing Record 0 of Set 12 | el obeid
# Processing Record 1 of Set 12 | al burayqah
# Processing Record 2 of Set 12 | ardakan
# Processing Record 3 of Set 12 | tual
# Processing Record 4 of Set 12 | sokode
# Processing Record 5 of Set 12 | saiha
# Processing Record 6 of Set 12 | toliara
# Processing Record 7 of Set 12 | norilsk
# Processing Record 8 of Set 12 | laguna
# Processing Record 9 of Set 12 | noosa heads
# Processing Record 10 of Set 12 | belo sur tsiribihina
# Processing Record 11 of Set 12 | turinskaya sloboda
# Processing Record 12 of Set 12 | nyagan
# Processing Record 13 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 12 | ciudad lazaro cardenas
# Processing Record 15 of Set 12 | tocopilla
# Processing Record 16 of Set 12 | ribeira brava
# Processing Record 17 of Set 12 | halifax
# Processing Record 18 of Set 12 | san luis de la loma
# Processing Record 19 of Set 12 | juneau
# Processing Record 20 of Set 12 | pekan bahapal
# City not found. Skipping...
# Processing Record 21 of Set 12 | geraldton
# Processing Record 22 of Set 12 | changleng
# Processing Record 23 of Set 12 | lerwick
# Processing Record 24 of Set 12 | martapura
# Processing Record 25 of Set 12 | ulladulla
# Processing Record 26 of Set 12 | okhotsk
# Processing Record 27 of Set 12 | tralee
# Processing Record 28 of Set 12 | vostochnyy
# Processing Record 29 of Set 12 | eldorado at santa fe
# Processing Record 30 of Set 12 | jobabo
# Processing Record 31 of Set 12 | birjand
# Processing Record 32 of Set 12 | todaraisingh
# Processing Record 33 of Set 12 | kilinochchi
# Processing Record 34 of Set 12 | adis zemen
# Processing Record 35 of Set 12 | montepuez
# Processing Record 36 of Set 12 | pauini
# Processing Record 37 of Set 12 | nueva gerona
# Processing Record 38 of Set 12 | saratamata
# City not found. Skipping...
# Processing Record 39 of Set 12 | cativa
# Processing Record 40 of Set 12 | magistral'nyy
# Processing Record 41 of Set 12 | kaa-khem
# Processing Record 42 of Set 12 | nashtarud
# City not found. Skipping...
# Processing Record 43 of Set 12 | chinde
# Processing Record 44 of Set 12 | mata-utu
# Processing Record 45 of Set 12 | zhizdra
# Processing Record 46 of Set 12 | saynshand
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    talnakh  69.4865   88.3972    -12.06        81          37        1.50
# 1     badger  64.8000 -147.5333      4.89        90          75        1.54
# 2  grytviken -54.2811  -36.5092     -2.44        74          16        3.79
# 3  ilulissat  69.2167  -51.1000     -3.99        80          75        6.69
# 4    ushuaia -54.8000  -68.3000      2.81        75          20        1.03
#
#   Country        Date
# 0      RU  1715183216
# 1      US  1715183217
# 2      GS  1715183218
# 3      GL  1715183219
# 4      AR  1715182949

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          talnakh  69.4865   88.3972    -12.06        81          37
# 1           badger  64.8000 -147.5333      4.89        90          75
# 2        grytviken -54.2811  -36.5092     -2.44        74          16
# 3        ilulissat  69.2167  -51.1000     -3.99        80          75
# 4          ushuaia -54.8000  -68.3000      2.81        75          20
#
#          Wind Speed Country        Date
# City_ID
# 0              1.50      RU  1715183216
# 1              1.54      US  1715183217
# 2              3.79      GS  1715183218
# 3              6.69      GL  1715183219
# 4              1.03      AR  1715182949

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.plot(city_data_df["Lat"],
         city_data_df["Max Temp"],
         linestyle = "none",
         marker = "o",
         markeredgecolor = "black",
         markeredgewidth = 0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2024-05-09)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.plot(city_data_df["Lat"],
         city_data_df["Humidity"],
         linestyle = "none",
         marker = "o",
         markeredgecolor = "black",
         markeredgewidth = 0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2024-05-09)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.plot(city_data_df["Lat"],
         city_data_df["Cloudiness"],
         linestyle = "none",
         marker = "o",
         markeredgecolor = "black",
         markeredgewidth = 0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2024-05-09)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.plot(city_data_df["Lat"],
         city_data_df["Wind Speed"],
         linestyle = "none",
         marker = "o",
         markeredgecolor = "black",
         markeredgewidth = 0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2024-05-07)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values, x_c = .1, y_c = .9):
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, xy=(x_c, y_c), xycoords = "axes fraction", fontsize = 15, color = "red")
    plt.xlabel("Latitude")
    plt.ylabel(y_values.name)
    print(f"The r-squared value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          talnakh  69.4865   88.3972    -12.06        81          37
# 1           badger  64.8000 -147.5333      4.89        90          75
# 3        ilulissat  69.2167  -51.1000     -3.99        80          75
# 5           bonthe   7.5264  -12.5050     30.56        67          91
# 8           hadibu  12.6500   54.0333     29.76        73          36
#
#          Wind Speed Country        Date
# City_ID
# 0              1.50      RU  1715183216
# 1              1.54      US  1715183217
# 3              6.69      GL  1715183219
# 5              4.52      SL  1715183220
# 8              1.20      YE  1715183223

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                          grytviken -54.2811  -36.5092     -2.44        74
# 4                            ushuaia -54.8000  -68.3000      2.81        75
# 6                          ankazoabo -22.2833   44.5167     23.63        46
# 7                           waitangi -43.9535 -176.5597      9.90        81
# 12       edinburgh of the seven seas -37.0676  -12.3116     14.27        68
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                16        3.79      GS  1715183218
# 4                20        1.03      AR  1715182949
# 6                 2        2.38      MG  1715183221
# 7               100        2.68      NZ  1715183222
# 12               87       10.57      SH  1715183226

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

linear_regression(x_values, y_values, 0.1, 0.1)
# Out:
# The r-squared value is: 0.6887872595517481

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

linear_regression(x_values, y_values, 0.3, 0.1)
# Out:
# The r-squared value is: 0.6885305765110127

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **There is a relationship beteween the max temp and latitude based on the scatter plots we created. As we look at the graphs we can conclude that as we move away from the equator the max temp decreases (as seen with the Northern Hemisphere plots) and as we move toward the equator the max temp increases (as seen with the Southern Hemisphere plots).**

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

linear_regression(x_values, y_values, 0.5, 0.1)
# Out:
# The r-squared value is: 0.022964113292962583

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

linear_regression(x_values, y_values, 0.5, 0.1)
# Out:
# The r-squared value is: 0.004111556751938922

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **As we look at both graphs that compares the correlation between a city's latitude and it's humidity, we can conclude that there is a little bit of a positive correlation between the two. Based on the graphs, as we move away from the southern hemisphere and make our way into the northern hemisphere we can notice an increase in the correlation between a city's humidity and latitude. Based on the r-squared values from both graphs we can conclude that the regression lines are not the best fit for the data points within the graph.**

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

linear_regression(x_values, y_values, 0.4, 0.125)
# Out:
# The r-squared value is: 0.015244716604294134

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

linear_regression(x_values, y_values, 0.4, 0.125)
# Out:
# The r-squared value is: 0.040556399672185536

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **Based on the graphs created comparing the cloudiness of a city and it's latitude, there is a positive correlation between a city's latitude and the cloudiness of that city. We can look at the plots for both northern and southern hemispheres and see that the relationship is the same for both. Now when it comes to the r-squared values for both graphs, one may say that the regression plot is not best fit for this data's variability.**

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

linear_regression(x_values, y_values, 0.4, 0.125)
# Out:
# The r-squared value is: 0.00015271873931926925

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

linear_regression(x_values, y_values, 0.4, 0.125)
# Out:
# The r-squared value is: 0.019390116757669957

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **Based on the graphs above, there is no correlation between a city' wind speed and it's latitude when looking at cities in the northern hemisphere. When it comes to the southern hemisphere is his a slight negative correlation with a r-squared value of 0.019. With that being said, one can say that as we move towards the equator there is a decrease in wind speed. With the r-squared value being so small but greater than 1, we can say that this regression line is not the best fit for the data points.**
